# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df=pd.read_csv('train.csv')

# %%
df
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
# ...

# %%
df.shape
# Out:
# (1460, 81)
# (1460, 81)

# %%
features_with_null=[feature for feature in df.columns if df[feature].isnull().sum().sum()>1]

# %%
for feature in features_with_null:
     print(feature,np.round(df[feature].isnull().mean(),4), '% missing values')
# Out:
# LotFrontage 0.1774 % missing values
# Alley 0.9377 % missing values
# MasVnrType 0.0055 % missing values
# MasVnrArea 0.0055 % missing values
# BsmtQual 0.0253 % missing values
# BsmtCond 0.0253 % missing values
# BsmtExposure 0.026 % missing values
# BsmtFinType1 0.0253 % missing values
# BsmtFinType2 0.026 % missing values
# FireplaceQu 0.4726 % missing values
# GarageType 0.0555 % missing values
# GarageYrBlt 0.0555 % missing values
# GarageFinish 0.0555 % missing values
# GarageQual 0.0555 % missing values
# GarageCond 0.0555 % missing values
# PoolQC 0.9952 % missing values
# Fence 0.8075 % missing values
# MiscFeature 0.963 % missing values
# LotFrontage 0.1774 % missing values
# Alley 0.9377 % missing values
# MasVnrType 0.0055 % missing values
# MasVnrArea 0.0055 % missing values
# BsmtQual 0.0253 % missing values
# BsmtCond 0.0253 % missing values
# BsmtExposure 0.026 % missing values
# BsmtFinType1 0.0253 % missing values
# BsmtFinType2 0.026 % missing values
# ...

# %%
for feature in features_with_null:
    data=df.copy()
    data[feature]=np.where(data[feature].isnull(),1,0)
    data.groupby(feature)['SalePrice'].median().plot.bar()
    plt.title(feature)
    plt.show()

# %%
print('id of house :',len(df.Id))
# Out:
# id of house : 1460
# id of house : 1460

# %%
numerical_features=[feature for feature in df.columns if df[feature].dtypes!='O']

# %%
df[numerical_features]
# Out:
#         Id  MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  \
# 0        1          60         65.0     8450            7            5
# 1        2          20         80.0     9600            6            8
# 2        3          60         68.0    11250            7            5
# 3        4          70         60.0     9550            7            5
# 4        5          60         84.0    14260            8            5
# ...    ...         ...          ...      ...          ...          ...
# 1455  1456          60         62.0     7917            6            5
# 1456  1457          20         85.0    13175            6            6
# 1457  1458          70         66.0     9042            7            9
# 1458  1459          20         68.0     9717            5            6
# 1459  1460          20         75.0     9937            5            6
#
#       YearBuilt  YearRemodAdd  MasVnrArea  BsmtFinSF1  ...  WoodDeckSF  \
# ...

# %%
print('no of num features :',len(numerical_features))
# Out:
# no of num features : 38
# no of num features : 38

# %%
catogorical_varibles=[feature for feature in df.columns if feature not in numerical_features+['Id']]

# %%
print('no of cat features :',len(catogorical_varibles))
# Out:
# no of cat features : 43
# no of cat features : 43

# %%
year_feature = [feature for feature in numerical_features if 'Yr' in feature or 'Year' in feature]

# %%
year_feature
# Out:
# ['YearBuilt', 'YearRemodAdd', 'GarageYrBlt', 'YrSold']
# ['YearBuilt', 'YearRemodAdd', 'GarageYrBlt', 'YrSold']

# %%
df['YrSold'].unique()
# Out:
# array([2008, 2007, 2006, 2009, 2010], dtype=int64)
# array([2008, 2007, 2006, 2009, 2010], dtype=int64)

# %%
for feature in year_feature:
    df.groupby(feature)['SalePrice'].median().plot()
    plt.title(feature)
    plt.show()

# %%
for feature in year_feature:
    if feature!='YrSold':
        #data=df.copy()
        diff=df['YrSold']-df[feature]
        plt.scatter(diff,df['SalePrice'])
        plt.title(feature)
        plt.show()

# %%
disctete_features=[feature for feature in numerical_features if len(df[feature].unique())<25 and feature not in year_feature + ['Id']]

# %%
len(disctete_features)
# Out:
# 17
# 17

# %%
for feature in disctete_features:
    df.groupby(feature)['SalePrice'].median().plot.bar()
    plt.title(feature)
    plt.show()

# %%
continuous_features=[ feature for feature in numerical_features if feature not in disctete_features +['Id']+year_feature]

# %%
len(continuous_features)
# Out:
# 16
# 16

# %%
for feature in continuous_features:
    plt.hist(df[feature],bins=25)
    #df.groupby(feature)['SalePrice'].median().plot()
    plt.title(feature)
    plt.show()

# %%
for feature in continuous_features:
    plt.scatter(df[feature],df['SalePrice'])
    plt.title(feature)
    plt.show()
